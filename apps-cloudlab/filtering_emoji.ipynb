# %%
# !python3 -m pip install 'emoji'
# Out:
# ...
#      |████████████████████████████████| 51kB 3.5MB/s eta 0:00:01
# ...
#   Created wheel for emoji: filename=emoji-0.5.4-cp37-none-any.whl size=42177 sha256=45aeee74780f53f86aaf4377a4d50b1539c15a5cb61c2683de3b6be7363ed9e5
#   Stored in directory: /Users/erikflaten/Library/Caches/pip/wheels/2a/a9/0a/4f8e8cce8074232aba240caca3fade315bb49fac68808d1a9c
# Successfully built emoji
# ...

# %%
import emoji

# %%
import pymongo

# %%
import nltk

# %%
import re
import pprint
from nltk.corpus.reader.plaintext import PlaintextCorpusReader
from nltk import word_tokenize

# %%
from nltk import sentiment

# %%
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/erikflaten/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# %%
#from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
import os
import re
import math
import string
import codecs
import json
import pymongo
from datetime import datetime
from pymongo import MongoClient
from itertools import product
from inspect import getsourcefile
from io import open

client = MongoClient('mongodb+srv://ef936963:Harvey54!@cluster0-yw0sn.mongodb.net/test?retryWrites=true&w=majority')
db = client.post_super_tuesday
debate219 = db.biden_sanders_debate

# %%
all_tweets = debate219.find()

# %%
all_text = [w['text'] for w in all_tweets]

# %%
project_txt_file = open("/Users/erikflaten/final_project.txt") 
raw = project_txt_file.read()
tokens = word_tokenize(raw)
project_text_nltk = nltk.Text(tokens)

# %%
only_emoji = [w for w in project_text_nltk if w in (eomoji_list)]

# %%
def extract_emojis(str):
  return ''.join(c for c in str if c in emoji.UNICODE_EMOJI)

# %%
#emoji_list

# %%
emoji_list=[c for c in emoji.UNICODE_EMOJI]
emoji_list[99]
emoji_one = emoji_list[0]
type(emoji_one)
# Out:
# str

# %%
#emoji_test = debate219.find({'text':{'$regex': [w for w in emoji_list]}})
def get_emoji_tweets(w):
    emoji_test = debate219.find({'text':{'$regex': w}}) 
    emoji_text = [t['text'] for t in emoji_test]
    return emoji_text

# %%
test_text_one = get_emoji_tweets(emoji_one)
test_text_one
# Out:
# ['Well, it seems that President Donald Trump 🥇 is the winner of the Joe Biden N Bernie Sanders debate tonight.',
#  'That is correct, Sir! 🥇']

# %%
test_text_one
text_list = [w for w in test_text_one]
text_list
# Out:
# ['Well, it seems that President Donald Trump 🥇 is the winner of the Joe Biden N Bernie Sanders debate tonight.',
#  'That is correct, Sir! 🥇']

# %%
'*' in ('*️⃣')
# Out:
# True

# %%
only_emoji = [w for w in project_text_nltk if w in (emoji_list)]

# %%
from nltk import FreqDist

# %%
fdist = FreqDist(only_emoji)

# %%
print(fdist.most_common(15))
# Out:
# [('😂', 8226), ('🙄', 4084), ('🤔', 3702), ('🤣', 2651), ('😭', 1873), ('👇', 1576), ('🇺🇸', 1293), ('😳', 1170), ('👀', 1155), ('👏', 1035), ('🔥', 941), ('😉', 925), ('😎', 923), ('🥺', 906), ('😔', 889)]

# %%
emoji_text_list = []
for e in emoji_list:
    #print(e)
    if '*' in e:
        print(e)
        print("skipped")
    elif len(get_emoji_tweets(e)) > 1:
        emoji_text_list.append(get_emoji_tweets(e))
# Out:
# *️⃣
# skipped
# *⃣
# skipped

# %%
#emoji_text_list[0:5]
len(emoji_list)
# Out:
# 2811

# %%
emoji_list[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-0afce34b2338> in <module>
# ----> 1 emoji_list[0]
#
# NameError: name 'emoji_list' is not defined

# %%
def score(twitter_text):
    count = 0
    neg = 0
    neu = 0
    pos = 0
    for tweet in twitter_text:
        count += 1
        vs = analyzer.polarity_scores(tweet)
        neg = neg + vs['neg']
        pos = pos + vs['pos']
    return ("Negative score: ", neg/count, "positive Score: ", pos/count)

# %%
emoji_text_list
# Out:
# [['Well, it seems that President Donald Trump 🥇 is the winner of the Joe Biden N Bernie Sanders debate tonight.',
#   'That is correct, Sir! 🥇'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['bernie be making me 🅱️ut 🥵😔',
#   '🅱️ERNERS, 🅱️ROCIALISTS, &amp; 🅱️OTS\n\nabsolutely love it thanks',
#   'Spoke too soon, FED done set interest rate to 0% \n\n🅱️algame dios'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['@mtracey You are 100 % right.\n\nWe should be denouncing Biden tons of other things he has done as well.\n\n( sorry 🇨🇦 )',
#   "@WEIRDWOLFX @23Hyper23 I like Biden. That's it. I'm 🇨🇦 I don't vote in the U.S. Get over it and move on.",
# ...

# %%
score(sanders_text)
# Out:
# ('Negative score: ',
#  0.08761554429517508,
#  'positive Score: ',
#  0.10165259000617399)
